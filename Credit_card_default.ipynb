# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # EDA

# %%
df = pd.read_csv('UCI_Credit_Card.csv')

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (30000, 25)

# %%
numerical_cols = df.select_dtypes(include= ('int64' , 'float64')).columns

# %%
df[numerical_cols].hist(figsize=(15,20) , bins=20 )
plt.tight_layout()

# %%
sns.barplot(x=df['SEX'] , y=df['default.payment.next.month'])
# Out:
# <Axes: xlabel='SEX', ylabel='default.payment.next.month'>

# %% [markdown]
# # Data Preprocessing and Cleaning

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df['EDUCATION'] = df['EDUCATION'].replace([0,4,5,6] , 4 , inplace=True)

# %%
df.drop(columns=['ID' , 'EDUCATION'] , inplace=True)

# %%
df['MARRIAGE'] = df['MARRIAGE'].replace(0, 3)

# %%
df['MARRIAGE'].unique()
# Out:
# array([1, 2, 3])

# %%
df.shape
# Out:
# (30000, 23)

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  \
# 0    20000.0    2         1   24      2      2     -1     -1     -2     -2
# 1   120000.0    2         2   26     -1      2      0      0      0      2
# 2    90000.0    2         2   34      0      0      0      0      0      0
# 3    50000.0    2         1   37      0      0      0      0      0      0
# 4    50000.0    1         1   57     -1      0     -1      0      0      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X = df.drop(columns=['default.payment.next.month'] , axis=1)
y = df['default.payment.next.month']

# %%
scaler = StandardScaler()

# %%
scaler.fit_transform(X)
# Out:
# array([[-1.13672015,  0.81016074, -1.06879721, ..., -0.30806256,
#         -0.31413612, -0.29338206],
#        [-0.3659805 ,  0.81016074,  0.84913055, ..., -0.24422965,
#         -0.31413612, -0.18087821],
#        [-0.59720239,  0.81016074,  0.84913055, ..., -0.24422965,
#         -0.24868274, -0.01212243],
#        ...,
#        [-1.05964618, -1.23432296,  0.84913055, ..., -0.03996431,
#         -0.18322937, -0.11900109],
#        [-0.67427636, -1.23432296, -1.06879721, ..., -0.18512036,
#          3.15253642, -0.19190359],
#        [-0.90549825, -1.23432296, -1.06879721, ..., -0.24422965,
#         -0.24868274, -0.23713013]])

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.20, random_state=42)

# %%
models = {
    'Logistic Regression' : LogisticRegression(),
     'GaussianNB' : GaussianNB(),
     'Knn' : KNeighborsClassifier(),
     'DecisionTreeClassifier' : DecisionTreeClassifier(),
      'SVM' : SVC()
}

# %%
for name, model in models.items(): 
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    print(f"{name} is {acc:.5f}")
# Out:
# Logistic Regression is 0.78117
# GaussianNB is 0.38167
# Knn is 0.75583
# DecisionTreeClassifier is 0.72333
# SVM is 0.78117

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'C': [0.01, 0.1, 1, 10],
    'penalty': ['l2'],
    'solver': ['liblinear', 'lbfgs']  # both work with l2
}

# %%
grid = GridSearchCV(
    LogisticRegression(),
    param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 1, 10], 'penalty': ['l2'],
#                          'solver': ['liblinear', 'lbfgs']},
#              scoring='accuracy')

# %%
pd.DataFrame(grid.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       3.894775      0.723736         0.066369        0.044491     0.01
# 1       0.775307      0.034182         0.007987        0.000489     0.01
# 2       4.425382      0.839236         0.011762        0.003503     0.10
# 3       0.674856      0.069560         0.010466        0.001772     0.10
# 4       4.111252      0.507618         0.009812        0.000979     1.00
# 5       0.652131      0.038874         0.009201        0.000741     1.00
# 6       3.400932      0.469907         0.014569        0.010328    10.00
# 7       0.653843      0.058011         0.010655        0.002206    10.00
#
#   param_penalty param_solver  \
# 0            l2    liblinear
# 1            l2        lbfgs
# 2            l2    liblinear
# 3            l2        lbfgs
# 4            l2    liblinear
# 5            l2        lbfgs
# 6            l2    liblinear
# 7            l2        lbfgs
#
# ...
